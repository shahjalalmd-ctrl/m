# %%
import datetime
print(f"Last updated: {datetime.datetime.now()}")
# Out:
# Last updated: 2026-09-10 16:35:32.574148

# %%
# Older versions of Jupyter Notebooks and matplotlib required this magic command 
# %matplotlib inline

# Import matplotlib and matplotlib.pyplot
import matplotlib
import matplotlib.pyplot as plt

print(f"matplotlib version: {matplotlib.__version__}")
# Out:
# matplotlib version: 3.11.1

# %%
# Create a simple plot, without the semi-colon
plt.plot()
# Out:
# []

# %%
# With the semi-colon
plt.plot();

# %%
# You could use plt.show() if you want
plt.plot()
plt.show()

# %%
# Let's add some data
plt.plot([1, 2, 3, 4]);

# %%
# Create some data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# %%
# Now a y-value too!
plt.plot(x, y);

# %%
# Creating a plot with the object-orientated verison
fig = plt.figure() # create a figure
ax = fig.add_subplot() # add an axes 
plt.show()

# %%
# Add some data to our previous plot 
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %%
# Create a Figure and multiple potential Axes and add some data
fig, ax = plt.subplots()
ax.plot(x, y);

# %%
# This is where the object orientated name comes from 
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# A quick Matplotlib Workflow
# The following workflow is a standard practice when creating a matplotlib plot:
#
# Import matplotlib - For example, import matplotlib.pyplot as plt).
# Prepare data - This may be from an existing dataset (data analysis) or from the outputs of a machine learning model (data science).
# Setup the plot - In other words, create the Figure and various Axes.
# Plot data to the Axes - Send the relevant data to the target Axes.
# Cutomize the plot - Add a title, decorate the colours, label each Axis.
# Save (optional) and show - See what your masterpiece looks like and save it to file if necessary.

# %%
# A matplotlib workflow

# 0. Import and get matplotlib ready
# %matplotlib inline # Not necessary in newer versions of Jupyter (e.g. 2022 onwards)
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot (Figure and Axes)
fig, ax = plt.subplots(figsize=(10,10))

# 3. Plot data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Sample Simple Plot", xlabel="x-axis", ylabel="y-axis")

# 5. Save & show
fig.savefig("/Users/shahjalalmd/Desktop/matplotlib/simple-plot.png")

# %% [markdown]
# 2. Making the most common type of plots using NumPy arrays

# %%
import numpy as np

# %%
# Create an array
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# The default plot is line
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Need to recreate our figure and axis instances when we want a new figure
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %% [markdown]
# Creating bar plots

# %%
# You can make plots from a dictionary
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dan's Nut Butter Store", ylabel="Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# Make some data from a normal distribution
x = np.random.randn(1000) # pulls data from a normal distribution

fig, ax = plt.subplots()
ax.hist(x);

# %%
x = np.random.random(1000) # random data from random distribution

fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# Creating Figures with multiple Axes with Subplots

# %%
# Option 1: Create 4 subplots with each Axes having its own variable name
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, 
                                             ncols=2, 
                                             figsize=(10, 5))

# Plot data to each axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Option 2: Create 4 subplots with a single ax variable
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))

# Index the ax variable to plot data
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# 3. Plotting data directly with pandas

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/shahjalalmd/Desktop/pandas/.venv/lib/python3.11/site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in /Users/shahjalalmd/Desktop/pandas/.venv/lib/python3.11/site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shahjalalmd/Desktop/pandas/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/shahjalalmd/Desktop/pandas/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Python (mhealth)

# %%
import pandas as pd

# %%
# Let's import the car_sales dataset 
# Note: The following two lines load the same data, one does it from a local file path, the other does it from a URL.
# car_sales = pd.read_csv("../data/car-sales.csv") # load data from local file
car_sales = pd.read_csv("/Users/shahjalalmd/Desktop/Matplotlib/car_sales.csv") # load data from raw URL (original: https://github.com/mrdbourke/zero-to-mastery-ml/blob/master/data/car-sales.csv)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Start with some dummy data
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2025', periods=1000))

# Note: ts = short for time series (data over time)
ts
# Out:
# 2025-01-01    0.231858
# 2025-01-02    1.091533
# 2025-01-03    0.435192
# 2025-01-04    0.994247
# 2025-01-05   -1.219432
#                 ...
# 2027-09-23    0.026567
# 2027-09-24   -1.418366
# 2027-09-25   -0.185893
# 2027-09-26   -1.860913
# 2027-09-27   -2.756644
# Freq: D, Length: 1000, dtype: float64

# %%
# Add up the values cumulatively
ts.cumsum()
# Out:
# 2025-01-01     0.231858
# 2025-01-02     1.323391
# 2025-01-03     1.758583
# 2025-01-04     2.752830
# 2025-01-05     1.533398
#                 ...
# 2027-09-23    59.757804
# 2027-09-24    58.339438
# 2027-09-25    58.153545
# 2027-09-26    56.292632
# 2027-09-27    53.535988
# Freq: D, Length: 1000, dtype: float64

# %%
# Plot the values over time with a line plot (note: both of these will return the same thing)
# ts.cumsum().plot() # kind="line" is set by default
ts.cumsum().plot(kind="line");

# %%
# Import the car sales data 
car_sales = pd.read_csv("/Users/shahjalalmd/Desktop/Matplotlib/car_sales.csv")

# Remove price column symbols
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', 
                                                    regex=True) # Tell pandas to replace using regex
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Add a date column
car_sales["Sale Date"] = pd.date_range("1/1/2024", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2024-01-01
# 1   Honda    Red          87899      4   5000 2024-01-02
# 2  Toyota   Blue          32549      3   7000 2024-01-03
# 3     BMW  Black          11179      5  22000 2024-01-04
# 4  Nissan  White         213095      4   3500 2024-01-05
# 5  Toyota  Green          99213      4   4500 2024-01-06
# 6   Honda   Blue          45698      4   7500 2024-01-07
# 7   Honda   Blue          54738      4   7000 2024-01-08
# 8  Toyota  White          60000      4   6250 2024-01-09
# 9  Nissan  White          31600      4   9700 2024-01-10

# %%
# Make total sales column (doesn't work, adds as string)
#car_sales["Total Sales"] = car_sales["Price"].cumsum()

# Oops... want them as int's not string
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-01-01         4000
# 1   Honda    Red          87899      4   5000 2024-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03        16000
# 3     BMW  Black          11179      5  22000 2024-01-04        38000
# 4  Nissan  White         213095      4   3500 2024-01-05        41500
# 5  Toyota  Green          99213      4   4500 2024-01-06        46000
# 6   Honda   Blue          45698      4   7500 2024-01-07        53500
# 7   Honda   Blue          54738      4   7000 2024-01-08        60500
# 8  Toyota  White          60000      4   6250 2024-01-09        66750
# 9  Nissan  White          31600      4   9700 2024-01-10        76450

# %%
car_sales.plot(x='Sale Date', y='Total Sales');

# %% [markdown]
# Scatter plot from a pandas DataFrame

# %%
# Note: In previous versions of matplotlib and pandas, have the "Price" column as a string would
# return an error
car_sales["Price"] = car_sales["Price"].astype(str)

# Plot a scatter plot
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# Convert Price to int
car_sales["Price"] = car_sales["Price"].astype(int)

# Plot a scatter plot
car_sales.plot(x="Odometer (KM)", y="Price", kind='scatter');

# %% [markdown]
# Bar plot from a pandas DataFrame

# %%
# Create 10 random samples across 4 columns
x = np.random.rand(10, 4)
x
# Out:
# array([[0.85170999, 0.79859862, 0.20799373, 0.84019797],
#        [0.97374562, 0.75733356, 0.67978159, 0.86847722],
#        [0.82518055, 0.98469935, 0.56444136, 0.96198706],
#        [0.66190422, 0.95136418, 0.95873717, 0.72616417],
#        [0.1652774 , 0.07896696, 0.01200052, 0.79572781],
#        [0.0214605 , 0.65781657, 0.42952399, 0.15239474],
#        [0.3744692 , 0.26861574, 0.53501135, 0.0137911 ],
#        [0.59180969, 0.03711512, 0.32964888, 0.5872677 ],
#        [0.9118144 , 0.73152233, 0.40535284, 0.80924812],
#        [0.21257682, 0.78890446, 0.89309721, 0.29618239]])

# %%
# Turn the data into a DataFrame
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.851710  0.798599  0.207994  0.840198
# 1  0.973746  0.757334  0.679782  0.868477
# 2  0.825181  0.984699  0.564441  0.961987
# 3  0.661904  0.951364  0.958737  0.726164
# 4  0.165277  0.078967  0.012001  0.795728
# 5  0.021460  0.657817  0.429524  0.152395
# 6  0.374469  0.268616  0.535011  0.013791
# 7  0.591810  0.037115  0.329649  0.587268
# 8  0.911814  0.731522  0.405353  0.809248
# 9  0.212577  0.788904  0.893097  0.296182

# %%
# Plot a bar chart
df.plot.bar();

# %%
# Plot a bar chart with the kind parameter
df.plot(kind='bar');

# %%
# Plot a bar chart from car_sales DataFrame
car_sales.plot(x="Make", 
               y="Odometer (KM)", 
               kind="bar");

# %% [markdown]
# Histogram plot from a pandas DataFrame

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10); # default number of bins (or groups) is 10

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
# Default number of bins is 10 
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
# Create a histogram of the Price column
car_sales["Price"].plot.hist(bins=10);

# %%
# Import the heart disease dataset
# Note: The following two lines create the same DataFrame, one just loads data from a local filepath where as the other downloads it directly from a URL.

# heart_disease = pd.read_csv("../data/heart-disease.csv") # load from local file path (requires data to be downloaded)
heart_disease = pd.read_csv("/Users/shahjalalmd/Desktop/Matplotlib/heart.csv") # load directly from raw URL (source: https://github.com/mrdbourke/zero-to-mastery-ml/blob/master/data/heart-disease.csv)
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Create a histogram of the age column
heart_disease["age"].plot.hist(bins=50);

# %% [markdown]
# Creating a plot with multiple Axes from a pandas DataFrame

# %%
# Inspect the data
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart_disease.plot.hist(figsize=(5, 20), 
                        subplots=True);

# %% [markdown]
# 4. Plotting more advanced plots from a pandas DataFrame

# %%
# Perform data analysis on patients over 50
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1016   65    1   3       138   282    1        0      174      0      1.4
# 1017   53    1   0       123   282    0        1       95      1      2.0
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1016      1   1     2       0
# 1017      1   2     3       0
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1024      1   1     3       0
#
# [710 rows x 14 columns]

# %%
# Create a scatter plot directly from the pandas DataFrame
over_50.plot(kind="scatter",
             x="age", 
             y="chol", 
             c="target", # colour the dots by target value
             figsize=(10, 6));

# %%
# Create a Figure and Axes instance
fig, ax = plt.subplots(figsize=(10, 6))

# Plot data from the DataFrame to the ax object
over_50.plot(kind="scatter", 
             x="age", 
             y="chol", 
             c="target", 
             ax=ax); # set the target Axes

# Customize the x-axis limits (to be within our target age ranges)
ax.set_xlim([45, 100]);

# %%
# Create Figure and Axes instance
fig, ax = plt.subplots(figsize=(10, 6))

# Plot data directly to the Axes intance
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"]) # Colour the data with the "target" column

# Customize the plot parameters 
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Setup the legend
ax.legend(*scatter.legend_elements(), 
          title="Target");

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(over_50["age"], 
                     over_50["chol"], 
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Add a legned
ax.legend(*scatter.legend_elements(), 
          title="Target")

# Add a meanline
ax.axhline(over_50["chol"].mean(),
           linestyle="--"); # style the line to make it look nice

# %% [markdown]
# Plotting multiple plots on the same figure (adding another plot to an existing one)

# %%
# Setup plot (2 rows, 1 column)
fig, (ax0, ax1) = plt.subplots(nrows=2, # 2 rows
                               ncols=1, # 1 column 
                               sharex=True, # both plots should use the same x-axis 
                               figsize=(10, 8))

# ---------- Axis 0: Heart Disease and Cholesterol Levels ----------

# Add data for ax0
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"])
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# ---------- Axis 1: Heart Disease and Max Heart Rate Levels ----------

# Add data for ax1
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"])

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate")
ax1.legend(*scatter.legend_elements(), title="Target")

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color='b', 
            linestyle='--', 
            label="Average")

# Title the figure
fig.suptitle('Heart Disease Analysis', 
             fontsize=16, 
             fontweight='bold');

# %% [markdown]
# 5. Customizing your plots (making them look pretty)

# %%
# Check the available styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'petroff6',
#  'petroff8',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Plot before changing style
car_sales["Price"].plot();

# %%
# Change the style of our future plots
plt.style.use("seaborn-v0_8-whitegrid")

# %%
# Plot the same plot as before
car_sales["Price"].plot();

# %%
# Change the plot style
plt.style.use("fivethirtyeight")

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", 
               y="Price", 
               kind="scatter");

# %%
# Change the plot style
plt.style.use("ggplot")

# %%
car_sales["Price"].plot.hist(bins=10);

# %%
# Change the plot style back to the default 
plt.style.use("default")

# %%
car_sales["Price"].plot.hist();

# %% [markdown]
# Customizing the title, legend and axis labels

# %%
# Create random data
x = np.random.randn(10, 4)
x
# Out:
# array([[-1.24757764, -0.88702167,  0.578523  ,  0.76697916],
#        [-1.16791842,  0.12202482,  0.92467024,  1.00538708],
#        [ 0.20879916, -0.37704587, -0.14172152, -0.02527184],
#        [ 2.10424134, -0.57776042,  0.06829369, -0.91230062],
#        [ 1.1551098 , -1.26778305, -1.54771018, -0.7382398 ],
#        [-0.81820803,  1.39067273, -0.89869803, -1.86165196],
#        [-0.57578394, -0.00885489,  0.09288586, -1.09865823],
#        [-0.02871692, -0.55739253, -0.28428744,  0.09456792],
#        [-1.38869803, -0.25880325, -0.14475637,  0.94801374],
#        [ 0.52563126,  0.01421017,  1.20598303, -1.93909127]])

# %%
# Turn data into DataFrame with simple column names
df = pd.DataFrame(x, 
                  columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -1.247578 -0.887022  0.578523  0.766979
# 1 -1.167918  0.122025  0.924670  1.005387
# 2  0.208799 -0.377046 -0.141722 -0.025272
# 3  2.104241 -0.577760  0.068294 -0.912301
# 4  1.155110 -1.267783 -1.547710 -0.738240
# 5 -0.818208  1.390673 -0.898698 -1.861652
# 6 -0.575784 -0.008855  0.092886 -1.098658
# 7 -0.028717 -0.557393 -0.284287  0.094568
# 8 -1.388698 -0.258803 -0.144756  0.948014
# 9  0.525631  0.014210  1.205983 -1.939091

# %%
# Create a bar plot
ax = df.plot(kind="bar")

# Check the type of the ax variable
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# Recreate the ax object
ax = df.plot(kind="bar")

# Set various attributes
ax.set(title="Random Number Bar Graph from DataFrame", 
       xlabel="Row number", 
       ylabel="Random number");
